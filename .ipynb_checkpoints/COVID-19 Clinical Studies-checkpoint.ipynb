# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline


from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
covidDF = pd.read_csv(r"COVID clinical trials.csv")

# %%
covidDF.head(5)
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# 1                               SARS-CoV-2 Infection
# 2                                            covid19
# 3                                              COVID
# 4  Maternal Fetal Infection Transmission|COVID-19...
#
#                                        Interventions  \
# 0   Diagnostic Test: ID Now™ COVID-19 Screening Test
# 1    Drug: Drug COVID19-0001-USR|Drug: normal saline
# 2  Other: Lung CT scan analysis in COVID-19 patients
# 3          Diagnostic Test: COVID 19 Diagnostic Test
# 4  Diagnostic Test: Diagnosis of SARS-Cov2 by RT-...
#
#                                     Outcome Measures  \
# 0  Evaluate the diagnostic performance of the ID ...
# 1  Change on viral load results from baseline aft...
# 2  A qualitative analysis of parenchymal lung dam...
# 3  Proportion of asymptomatic subjects|Proportion...
# 4  COVID-19 by positive PCR in cord blood and / o...
#
#                                Sponsor/Collaborators  ...         Other IDs  \
# 0              Groupe Hospitalier Paris Saint Joseph  ...       COVID-IDNow
# 1                         United Medical Specialties  ...  COVID19-0001-USR
# 2                       University of Milano Bicocca  ...       TAC-COVID19
# 3                    Hong Kong Sanatorium & Hospital  ...        RC-2020-08
# 4  Centre Hospitalier Régional d'Orléans|Centre d...  ...      CHRO-2020-10
#
#          Start Date Primary Completion Date   Completion Date  \
# 0  November 9, 2020       December 22, 2020    April 30, 2021
# 1  November 2, 2020       December 15, 2020  January 29, 2021
# 2       May 7, 2020           June 15, 2021     June 15, 2021
# 3      May 25, 2020           July 31, 2020   August 31, 2020
# 4       May 5, 2020                May 2021          May 2021
#
#        First Posted Results First Posted Last Update Posted  \
# 0     March 8, 2021                  NaN      March 8, 2021
# 1  October 20, 2020                  NaN   October 20, 2020
# 2      May 20, 2020                  NaN   November 9, 2020
# 3      June 4, 2020                  NaN       June 4, 2020
# 4      May 20, 2020                  NaN       June 4, 2020
#
#                                            Locations Study Documents  \
# 0  Groupe Hospitalier Paris Saint-Joseph, Paris, ...             NaN
# 1       Cimedical, Barranquilla, Atlantico, Colombia             NaN
# 2  Ospedale Papa Giovanni XXIII, Bergamo, Italy|P...             NaN
# 3  Hong Kong Sanatorium & Hospital, Hong Kong, Ho...             NaN
# 4                       CHR Orléans, Orléans, France             NaN
#
#                                            URL
# 0  https://ClinicalTrials.gov/show/NCT04785898
# 1  https://ClinicalTrials.gov/show/NCT04595136
# 2  https://ClinicalTrials.gov/show/NCT04395482
# 3  https://ClinicalTrials.gov/show/NCT04416061
# 4  https://ClinicalTrials.gov/show/NCT04395924
#
# [5 rows x 27 columns]

# %%
covidDF.describe()
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %%
covidDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
#  14  Funded Bys               5783 non-null   object
#  15  Study Type               5783 non-null   object
#  16  Study Designs            5748 non-null   object
#  17  Other IDs                5782 non-null   object
#  18  Start Date               5749 non-null   object
#  19  Primary Completion Date  5747 non-null   object
#  20  Completion Date          5747 non-null   object
#  21  First Posted             5783 non-null   object
#  22  Results First Posted     36 non-null     object
#  23  Last Update Posted       5783 non-null   object
#  24  Locations                5198 non-null   object
#  25  Study Documents          182 non-null    object
#  26  URL                      5783 non-null   object
# dtypes: float64(1), int64(1), object(25)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Coverting date columns to DateTime fields
#
# Converting the date fields to correct DateTime data type as DType is object

# %%
covidDF['Start Date'] = pd.to_datetime(covidDF['Start Date'])
covidDF['Primary Completion Date'] = pd.to_datetime(covidDF['Primary Completion Date'])
covidDF['Completion Date'] = pd.to_datetime(covidDF['Completion Date'])
covidDF['First Posted'] = pd.to_datetime(covidDF['First Posted'])
covidDF['Results First Posted'] = pd.to_datetime(covidDF['Results First Posted'])
covidDF['Last Update Posted'] = pd.to_datetime(covidDF['Last Update Posted'])

# %%
date = covidDF[['Start Date','Primary Completion Date', 'Completion Date', 'First Posted', 'Results First Posted', 'Last Update Posted']]
date
# Out:
#      Start Date Primary Completion Date Completion Date       First Posted  \
# 0    2020-11-09              2020-12-22      2021-04-30      March 8, 2021
# 1    2020-11-02              2020-12-15      2021-01-29   October 20, 2020
# 2    2020-05-07              2021-06-15      2021-06-15       May 20, 2020
# 3    2020-05-25              2020-07-31      2020-08-31       June 4, 2020
# 4    2020-05-05              2021-05-01      2021-05-01       May 20, 2020
# ...         ...                     ...             ...                ...
# 5778 2020-03-23              2022-08-01      2023-04-01       July 8, 2019
# 5779 2021-04-01              2024-11-01      2024-12-01  December 23, 2020
# 5780 2021-02-10              2021-07-01      2021-07-01   February 5, 2021
# 5781 2021-03-22              2022-05-31      2022-12-31     March 18, 2021
# 5782 2021-02-01              2024-02-01      2025-02-01  December 22, 2020
#
#      Results First Posted Last Update Posted
# 0                     NaN      March 8, 2021
# 1                     NaN   October 20, 2020
# 2                     NaN   November 9, 2020
# 3                     NaN       June 4, 2020
# 4                     NaN       June 4, 2020
# ...                   ...                ...
# 5778                  NaN      April 2, 2021
# 5779                  NaN  February 10, 2021
# 5780                  NaN  February 24, 2021
# 5781                  NaN      April 1, 2021
# 5782                  NaN  December 22, 2020
#
# [5783 rows x 6 columns]

# %%
covidDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
#  14  Funded Bys               5783 non-null   object
#  15  Study Type               5783 non-null   object
#  16  Study Designs            5748 non-null   object
#  17  Other IDs                5782 non-null   object
#  18  Start Date               5749 non-null   datetime64[ns]
#  19  Primary Completion Date  5747 non-null   datetime64[ns]
#  20  Completion Date          5747 non-null   datetime64[ns]
#  21  First Posted             5783 non-null   datetime64[ns]
#  22  Results First Posted     36 non-null     datetime64[ns]
#  23  Last Update Posted       5783 non-null   datetime64[ns]
#  24  Locations                5198 non-null   object
#  25  Study Documents          182 non-null    object
#  26  URL                      5783 non-null   object
# dtypes: datetime64[ns](6), float64(1), int64(1), object(19)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Creating a DataFrame which shows count of unique values, count of null values and percentage of null values in the entire dataset

# %%
from collections import defaultdict 
def NullUnique(df):
    dic = defaultdict(list)
    for col in df.columns:
        dic['Feature'].append(col)
        dic['NumUnique'].append(len(df[col].unique()))
        dic['NumNull'].append(df[col].isnull().sum())
        dic['%Null'].append(round(df[col].isnull().sum()/df.shape[0] * 100,2))
    return pd.DataFrame(dict(dic)).sort_values(['%Null'],ascending=False).style.background_gradient()

NullUnique(covidDF)
# Out:
# <style  type="text/css" >
# #T_39f15905_ba73_11eb_bb79_bc17b884c46crow0_col1,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow6_col2,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow6_col3,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow7_col2,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow7_col3,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow8_col2,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow8_col3,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow9_col2,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow9_col3,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow10_col2,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow10_col3,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow11_col2,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow11_col3,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow18_col1{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_39f15905_ba73_11eb_bb79_bc17b884c46crow0_col2,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow0_col3,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow16_col1,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow19_col1,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow25_col1,#T_39f15905_ba73_11eb_bb79_bc17b884c46crow26_col1{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T
#                         <td id="T_39f15905_ba73_11eb_bb79_bc17b884c46crow1_col0" class="data row1 col0" >Study Documents</td>
#                         <td id="T_39f15905_ba73_11eb_bb79_bc17b884c46crow1_col1" class="data row1 col1" >183</td>
#                         <td id="T_39f15905_ba73_11eb_bb79_bc17b884c46crow1_col2" class="data row1 col2" >5601</td>
#                         <td id="T_39f15905_ba73_11eb_bb79_bc17b884c46crow1_col3" class="data row1 col3" >96.850000</td>
#             </tr>
#             <tr>
#                         <th id="T_39f15905_ba73_11eb_bb79_bc17b884c46clevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_39f15905_ba73_11eb_bb79_bc17b884c46crow2_col0" class="data row2 col0" >Acronym</td>
#                         <td id="T_39f15905_ba73_11eb_bb79_bc17b884c46crow2_col1" class="data row2 col1" >2339</td>
#                         <td id="T_39f15905_ba73_11eb_bb79_bc17b884c46crow2_col2" class="data row2 col2" >3303</td>

# %% [markdown]
# ### Visualization
#
# Guide questions to get some insights on the dataset<br>
# 1. How many phases are there in the study?<br>
# 2. What are the status of the study
# 3. What are the age of the participants in the study
# 4. What are the location the study is conducted

# %%
import plotly.express as px
fig = px.pie(covidDF,'Study Results')
fig.update_layout(title='Percentage Results on the Study?', template="plotly_dark")
fig.show()
# Out:
# <div>                            <div id="68d37117-39d1-463d-8933-b3d35f0a457c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68d37117-39d1-463d-8933-b3d35f0a457c")) {                    Plotly.newPlot(                        "68d37117-39d1-463d-8933-b3d35f0a457c",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Study Results=%{label}<extra></extra>", "labels": ["No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "Has Results", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "Has Results", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results Available", "No Results ...

# %% [markdown]
# #### Phases in the Study

# %%
phases = covidDF.groupby('Phases')['Rank'].count().sort_values(ascending=False).index
count = covidDF.groupby('Phases')['Rank'].count().sort_values(ascending=False).values
fig = px.bar(covidDF, x=phases, y=count, color=phases, text=count)

fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(uniformtext_minsize=8)
fig.update_layout(xaxis_tickangle=-45)
fig.update_layout(title="Clinical Study Phases",
    xaxis_title="Phases",
    yaxis_title="Count",
    legend_title="Phases",
    template="plotly_dark")
# Out:
# <div>                            <div id="c711cb2d-23f8-4dce-95f2-03309fd8ce29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c711cb2d-23f8-4dce-95f2-03309fd8ce29")) {                    Plotly.newPlot(                        "c711cb2d-23f8-4dce-95f2-03309fd8ce29",                        [{"alignmentgroup": "True", "hovertemplate": "color=Not Applicable<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Not Applicable", "marker": {"color": "#636efa"}, "name": "Not Applicable", "offsetgroup": "Not Applicable", "orientation": "v", "showlegend": true, "text": [1354.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Not Applicable"], "xaxis": "x", "y": [1354], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Phase 2<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Phase 2", "marker": {"color": "#EF553B"}, "name": "Phase 2", "offsetgroup": "Phase 2", "orientation": "v", "showlegend": true, "text": [685.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Phase 2"], "xaxis": "x", "y": [685], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Phase 3<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Phase 3", "marker": {"color": "#00cc96"}, "name": "Phase 3", "offsetgroup": "Phase 3", "orientation": "v", "showlegend": true, "text": [450.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Phase 3"], "xaxis": "x", "y": [450], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Phase 1<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Phase 1", "marker": {"color": "#ab63fa"}, "name": "Phase 1", "offsetgroup": "Phase 1", "orientation": "v", "showlegend": true, "text": [234.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Phase 1"], "xaxis": "x", "y": [234], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Phase 2|Phase 3<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Phase 2|Phase 3", "marker": {"color": "#FFA15A"}, "name": "Phase 2|Phase 3", "offsetgroup": "Phase 2|Phase 3", "orientation": "v", "showlegend": true, "text": [200.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Phase 2|Phase 3"], "xaxis": "x", "y": [200], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Phase 1|Phase 2<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Phase 1|Phase 2", "marker": {"color": "#19d3f3"}, "name": "Phase 1|Phase 2", "offsetgroup": "Phase 1|Phase 2", "orientation": "v", "showlegend": true, "text": [192.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Phase 1|Phase 2"], "xaxis": "x", "y": [192], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Phase 4<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Phase 4", "marker": {"color": "#FF6692"}, "name": "Phase 4", "offsetgroup": "Phase 4", "orientation": "v", "showlegend": true, "text": [161.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Phase 4"], "xaxis": "x", "y": [161], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Early Phase 1<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "Early Phase 1", "marker": {"color": "#B6E880"}, "name": "Early Phase 1", "offsetgroup": "Early Phase 1", "orientation": "v", "showlegend": true, "text": [46.0], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Early Phase 1"], "xaxis": "x", "y": [46], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Phases"}, "tra ...

# %% [markdown]
# #### Status of the study

# %%
pd.crosstab(covidDF['Phases'],covidDF['Status']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Phases'>

# %%
df = pd.crosstab(covidDF['Phases'],covidDF['Status'])
df.reset_index('Phases')
# Out:
# Status           Phases  Active, not recruiting  Completed  \
# 0         Early Phase 1                       7          3
# 1        Not Applicable                     111        226
# 2               Phase 1                      44         38
# 3       Phase 1|Phase 2                      26         17
# 4               Phase 2                      81         78
# 5       Phase 2|Phase 3                      15         20
# 6               Phase 3                      59         56
# 7               Phase 4                       8         22
#
# Status  Enrolling by invitation  Not yet recruiting  Recruiting  Suspended  \
# 0                             4                   5          22          2
# 1                            54                 282         647          2
# 2                             1                  42          98          0
# 3                             3                  46          92          2
# 4                            10                 114         343          4
# 5                             1                  46         102          4
# 6                             6                  89         196          9
# 7                             6                  30          81          2
#
# Status  Terminated  Withdrawn
# 0                0          3
# 1               13         19
# 2                4          7
# 3                2          4
# 4               25         30
# 5                6          6
# 6               15         20
# 7                5          7

# %%
plt.style.use('dark_background')
iplot(df.iplot(asFigure=True, kind='bar', title='Status for each Phase in the Clinical Study', theme='solar'))
# Out:
# <div>                            <div id="f1eeaab5-fe9f-404c-9d8a-8e1e4186a4d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1eeaab5-fe9f-404c-9d8a-8e1e4186a4d2")) {                    Plotly.newPlot(                        "f1eeaab5-fe9f-404c-9d8a-8e1e4186a4d2",                        [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Active, not recruiting", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [7, 111, 44, 26, 81, 15, 59, 8]}, {"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "Completed", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [3, 226, 38, 17, 78, 20, 56, 22]}, {"marker": {"color": "rgba(50, 171, 96, 0.6)", "line": {"color": "rgba(50, 171, 96, 1.0)", "width": 1}}, "name": "Enrolling by invitation", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [4, 54, 1, 3, 10, 1, 6, 6]}, {"marker": {"color": "rgba(128, 0, 128, 0.6)", "line": {"color": "rgba(128, 0, 128, 1.0)", "width": 1}}, "name": "Not yet recruiting", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [5, 282, 42, 46, 114, 46, 89, 30]}, {"marker": {"color": "rgba(219, 64, 82, 0.6)", "line": {"color": "rgba(219, 64, 82, 1.0)", "width": 1}}, "name": "Recruiting", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [22, 647, 98, 92, 343, 102, 196, 81]}, {"marker": {"color": "rgba(0, 128, 128, 0.6)", "line": {"color": "rgba(0, 128, 128, 1.0)", "width": 1}}, "name": "Suspended", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [2, 2, 0, 2, 4, 4, 9, 2]}, {"marker": {"color": "rgba(255, 255, 51, 0.6)", "line": {"color": "rgba(255, 255, 51, 1.0)", "width": 1}}, "name": "Terminated", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [0, 13, 4, 2, 25, 6, 15, 5]}, {"marker": {"color": "rgba(128, 128, 0, 0.6)", "line": {"color": "rgba(128, 128, 0, 1.0)", "width": 1}}, "name": "Withdrawn", "orientation": "v", "text": "", "type": "bar", "x": ["Early Phase 1", "Not Applicable", "Phase 1", "Phase 1|Phase 2", "Phase 2", "Phase 2|Phase 3", "Phase 3", "Phase 4"], "y": [3, 19, 7, 4, 30, 6, 20, 7]}],                        {"legend": {"bgcolor": "#151516", "font": {"color": "#D9D9D9"}}, "paper_bgcolor": "#151516", "plot_bgcolor": "#151516", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outli ...
